# %% [markdown]
# <a href="https://colab.research.google.com/github/NinaHRO/CIS-3902-AI-and-ML/blob/main/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive, files

# %%
# 1. Reading a CSV file using Pandas from a URL
# The original URL pointed to the GitHub HTML page of the file, not the raw data.
# Changed to the raw GitHub content URL.
csv_url = 'https://raw.githubusercontent.com/NinaHRO/CIS-3902-AI-and-ML/00ccf02f1e39a5a2e4791bc12cb5f8e9bc818ee6/housingData.csv'
# The original 'columns' list is not needed as the CSV has its own header.
# Read the dataset with the correct separator and infer header.
df_boston = pd.read_csv(csv_url, sep=',', header=0) # Use comma as separator and infer header from the first row
# Show the first few rows
print(df_boston.head())
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
# 1. Reading a CSV file using Pandas from a URL
# The original URL pointed to the GitHub HTML page of the file, not the raw data.
# Changed to the raw GitHub content URL.
csv_url = 'https://raw.githubusercontent.com/NinaHRO/CIS-3902-AI-and-ML/00ccf02f1e39a5a2e4791bc12cb5f8e9bc818ee6/housingData.csv'
# The original 'columns' list is not needed as the CSV has its own header.
# Read the dataset with the correct separator and infer header.
df_boston = pd.read_csv(csv_url, sep=',', header=0) # Use comma as separator and infer header from the first row
# Show the first few rows
print(df_boston.head())
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
# 2. Reading raw data from a GitHub URL (ensure the URL is raw)
raw_github_url = 'https://raw.githubusercontent.com/NinaHRO/CIS-3902-AI-and-ML/main/president_polls_2016.csv'
df_raw_url = pd.read_csv(raw_github_url)
print("\nRaw data from GitHub URL:")
print(df_raw_url.head())
# Out:
# Raw data from GitHub URL:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
#
#   state  startdate    enddate                  pollster grade  ...  \
# 0  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+  ...
# 1  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B  ...
# 2  U.S.  11/2/2016  11/6/2016                     Ipsos    A-  ...
# 3  U.S.  11/4/2016  11/7/2016                    YouGov     B  ...
# 4  U.S.  11/3/2016  11/6/2016          Gravis Marketing    B-  ...
#
#    adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...

# %%
from google.colab import drive, files
# 3. Reading a CSV file from Google Drive
drive.mount('/content/drive')  # Mount Google Drive
#
# Please update the path below to the actual location of your 'excel-sample.csv' file in your Google Drive.
# Example: '/content/drive/MyDrive/my_folder/excel-sample.csv'
file_path = '/content/drive/MyDrive/cis3902/excel-sample.csv'  # Updated placeholder path
df_drive = pd.read_csv(file_path)
print("\nCSV from Google Drive:")
print(df_drive.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# CSV from Google Drive:
#     id  gpa      level oncampus
# 0  100  3.3     Senior       No
# 1  200  3.2     Senior       No
# 2  300  4.0  FirstYear      Yes
# 3  400  2.1  Sophomore      Yes
# 4  500  1.9  FirstYear       No

# %%
# 4. Uploading and reading an Excel file (.xlsx)
uploaded = files.upload()  # Prompt to upload file

for filename in uploaded.keys():
    df_excel = pd.read_excel(filename)
    print("\nExcel file uploaded:")
    print(df_excel.head())
# Out:
#      <input type="file" id="files-2dc3e8fc-331e-4655-a16c-9999cf29510b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2dc3e8fc-331e-4655-a16c-9999cf29510b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
